# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random
from matplotlib import style

# %%
plt.subplot(2,2,1)
plt.pie([1])

plt.subplot(2,2,2)
plt.pie([1,2])

plt.subplot(2,2,3)
plt.pie([1,2,3])

plt.subplot(2,2,4)
plt.pie([1,2,3,4])
plt.show()

# %%
plt.figure(figsize=(16,9))

plt.subplot(3,2,1)
day=[1,2,3,4,5,6,7]
temperature=[40,35.5,41,36.9,39.7,40.2,41]


style.use('ggplot')
plt.plot(day , temperature, 'go--', linewidth=3 ,markersize=10)
plt.title("Ryk Temperature" ,fontsize=20)
plt.legend(['temp line'], loc=4 )
plt.xlabel('days' , fontsize=20) 
plt.ylabel('temperature', fontsize=20)
plt.grid( linestyle=':', linewidth=1)
plt.show()
plt.figure(figsize=(16,9))
#----------------------------------------------------------------------------------------------------End
plt.subplot(3,2,2)
Cs_students_age=np.random.randint(15,40 ,(100))
Is_students_age=np.random.randint(20,40 ,(100))
bins= [15,20,25,30,35,40,45]
#plt.figure(figsize=(16,9))
plt.hist([Cs_students_age, Is_students_age] ,bins ,rwidth=0.8 , color=['b', 'y'],histtype='bar' ,label=['cs student', 'Is students'])
#plt.hist(Is_students_age, bins ,rwidth=0.8 , color='y',histtype='bar' ,label='Is student')
plt.title("Cs&Is Students", fontsize=10)
plt.xlabel('studnets')
plt.ylabel('age')
plt.legend(loc=4)
plt.show()
plt.figure(figsize=(16,9))
#---------------------------------------------------------------------------------------------------End
plt.subplot(3,2,3)
df_world_pop=pd.read_csv('D:\\Paython\\world_population.csv',nrows=200)
df_world_pop.shape
x=df_world_pop['Area (km²)']
y=df_world_pop['World Population Percentage']
plt.scatter(x,y ,c='b',s=100,linewidths=8,edgecolors='m', alpha=0.5)
plt.scatter(x, df_world_pop['Growth Rate'],c='r',s=100,linewidths=8,edgecolors='y', alpha=0.5)
plt.title('World Population & Growth Rate',fontsize=20.0)
plt.xlabel('Area (km²)',fontsize=15)
plt.figure(figsize=(16,9))
plt.subplot(3,2,4)
classes=['java','c','paython','bio','Ml']
class_1=[23,26,43,34,42]
explode=[0,0.2,0,0.05,0]
textprops={'fontsize':15}
colors=['r','m','y','b','g']

wedgeprops={'linewidth': 4,'edgecolor':'k','width':2}
plt.pie(class_1, labels =classes,explode=explode,colors=colors,textprops=textprops,shadow=True,radius=2,
        labeldistance=1.6,normalize=True,autopct="%0.1f%%",startangle=270,pctdistance=0.8, wedgeprops= wedgeprops,  
        frame=True,rotatelabels=True, center=(2, 3),counterclock=True,)
#plt.legend()
plt.figure(figsize=(16,9))
plt.subplot(3,2,5)
classes=['paython','cloud','AI', 'java','c++']
    
class_1=[22,34,32,24,54]

class_2=[67,65,43,23,12]

class_3=[77,68,49,28,92]



classes_index=np.arange(len(classes))

width=0.5

plt.bar(classes_index,class_1 ,width,color='y')

plt.bar(classes_index+width,class_2 ,width,color='r')

plt.xticks(classes_index+width,classes)

plt.bar(classes_index+width+width+width,class_3 ,width,color='b')

plt.title('Bar chart for students', fontsize=20)

plt.xlabel('Subjects',fontsize=15)

plt.ylabel('students',fontsize=15)

style.use('ggplot')
plt.figure(figsize=(16,9))
plt.subplot(3,2,6, projection='polar', facecolor='k')
plt.show()
